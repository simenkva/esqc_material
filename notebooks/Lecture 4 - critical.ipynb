# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  
# %matplotlib inline

# %%
def f(x,y):
    #return (x**3 - y**2*x - 2*x*y**2)/(x**2 + y**2)
    return np.exp(-(x**2 + y**2))*(1-x**2)*y**2

# %%
def plot_fun_2d(f, x_lim, y_lim, nx=200,ny=200, frange = (-.75,.75)):
    
    x = np.linspace(x_lim[0], x_lim[1], nx)
    y = np.linspace(y_lim[0], y_lim[1], ny)
    xx,yy = np.meshgrid(x,y)

    z = f(xx,yy)
    print (z.shape)
    
    fig = plt.figure()
#    ax = fig.add_subplot(111, projection='3d')
#    ax.plot_surface(xx,yy,z)
    plt.imshow(z,extent=[*x_lim, *y_lim])
    plt.colorbar()
    CS = plt.contour(z,levels=np.linspace(*frange,21), colors='w',extent = [*x_lim, *y_lim])
    plt.gca().clabel(CS, inline=True, fontsize=10)
    plt.xlabel('x')
    plt.ylabel('y')

# %%
x_lim = (-2,2)
y_lim = (-2,2)
plot_fun_2d(f, x_lim, y_lim)
# Out:
# (200, 200)

# %%
plt.savefig('gaussian-2d.pdf')

# %%
def surf_plot(f,x_lim=(-1,1),y_lim=(-1,1)):
    nx = 200
    ny = 200
    x = np.linspace(x_lim[0], x_lim[1], nx)
    y = np.linspace(y_lim[0], y_lim[1], ny)
    xx,yy = np.meshgrid(x,y)

    z = f(xx,yy)
    
    fig = plt.figure(figsize=(4,3))
    ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(xx,yy,z)
#     plt.imshow(z,extent=[*x_lim, *y_lim])
#     plt.colorbar()
#     CS = plt.contour(z,levels=np.linspace(*frange,21), colors='w',extent = [*x_lim, *y_lim])
#     plt.gca().clabel(CS, inline=True, fontsize=10)
    plt.xlabel('x')
    plt.ylabel('y')

# %%
surf_plot(lambda x,y: x**2 + y**2)
plt.savefig('minimum.pdf')
surf_plot(lambda x,y: x**2 - y**2)
plt.savefig('saddle.pdf')
surf_plot(lambda x,y: -x**2 - y**2)
plt.savefig('maximum.pdf')
# Out:
# <img src="data:image/png;base64,..." width="400">
# <img src="data:image/png;base64,..." width="400">
# <img src="data:image/png;base64,..." width="400">

# %%
surf_plot(lambda x,y: ((1-x -1j*y)**(-1)).real, x_lim=(0,1.1), y_lim=(0,1.1))
surf_plot(lambda x,y: ((1-x -1j*y)**(-1)).imag)
# Out:
# <img src="data:image/png;base64,..." width="400">
# <img src="data:image/png;base64,..." width="400">

# %%
nx = 1000
x = np.linspace(x_lim[0], x_lim[1], nx)
plt.figure()
plt.plot(x,g(x))
plt.xlabel('$x$')
plt.ylabel(f'$f(x,{y0})$')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, '$f(x,0.5)$')

# %%
plt.savefig('section.pdf')

# %%
def f(x,y):
    #return (x**3 - y**2*x - 2*x*y**2)/(x**2 + y**2)
    return np.sign(x)*np.sign(y)*(np.abs(x)*np.abs(y))**(1/3)

# %%
x_lim = (-2,2)
y_lim = (-2,2)
plot_fun_2d(f, x_lim, y_lim, frange = (-1.5,1.5))
# Out:
# (200, 200)
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig('pdiff-example1.pdf')

# %%
g = lambda x: f(x,x)

nx = 1000
x = np.linspace(x_lim[0], x_lim[1], nx)
plt.figure()
plt.plot(x,g(x))
plt.xlabel('$x$')
plt.ylabel(f'$f(x,x)$')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, '$f(x,x)$')

# %%
plt.savefig('pdiff-example2.pdf')
